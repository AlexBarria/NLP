# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## Predicción de próxima palabra

# %% [markdown]
# ### Objetivo
# El objetivo es utilizar documentos / corpus para crear embeddings de palabras basado en ese contexto utilizando la layer Embedding de Keras. Se utilizará esos embeddings junto con layers LSTM para predeccir la próxima posible palabra.

# %%
import random
import io
import pickle

import numpy as np
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout

# %% [markdown]
# ### Datos
# Utilizaremos como dataset canciones de bandas de habla inglés.

# %%
# Descargar la carpeta de dataset
import os
import platform
if os.access('./songs_dataset', os.F_OK) is False:
    if os.access('songs_dataset.zip', os.F_OK) is False:
        if platform.system() == 'Windows':
            # !curl https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/main/datasets/songs_dataset.zip -o songs_dataset.zip
        else:
            # !wget songs_dataset.zip https://github.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/raw/main/datasets/songs_dataset.zip
    # !unzip -q songs_dataset.zip   
else:
    print("El dataset ya se encuentra descargado")

# %%
# Posibles bandas
os.listdir("./songs_dataset/")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/Colab_Notebooks/NLP/Clase 4'
# Out:
# /content/drive/MyDrive/Colab_Notebooks/NLP/Clase 4

# %%
# Armar el dataset utilizando salto de línea para separar las oraciones/docs
df = pd.read_csv('ESDLA_1cap.txt', sep='\n', header=None)
df.head()
# Out:
#                                                    0
# 0  Este libro trata principalmente de los Hobbits...
# 1  sus páginas mucho del carácter y algo de la hi...
# 2  encontrarse más información en los extractos d...
# 3  Oeste que ya han sido publicados con el título...
# 4  origen en los primeros capítulos del Libro Roj...

# %%
print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 280

# %% [markdown]
# ### 1 - Ejemplo de Preprocesamiento
# - Hay que transformar las oraciones en tokens.
# - Dichas oraciones hay que ajustarlas al tamaño fijo de nuestra sentencia de entrada al modelo.
# - Hay que separar las palabras objetivos (target) que el modelo debe predecir en cada sentencia armada.

# %%
from keras.preprocessing.text import Tokenizer # equivalente a ltokenizer de nltk
from keras.preprocessing.text import text_to_word_sequence # equivalente a word_teokenize de nltk
from keras.preprocessing.sequence import pad_sequences # se utilizará para padding

# largo de la secuencia, incluye seq input + word output
train_len = 4

# %%
# Ejemplo de como transformar una oración a tokens usando keras
text = df.loc[0,0]
text
# Out:
# 'Este libro trata principalmente de los Hobbits, y el lector descubrirá en'

# %%
tokens = text_to_word_sequence(text) # entran oraciones -> salen vectores de N posiciones (tokens)
tokens
# Out:
# ['este',
#  'libro',
#  'trata',
#  'principalmente',
#  'de',
#  'los',
#  'hobbits',
#  'y',
#  'el',
#  'lector',
#  'descubrirá',
#  'en']

# %% [markdown]
# 1.1 - Transformar las oraciones en secuencias (tokens) de palabras

# %%
# Recorrer todas las filas y transformar las oraciones
# en secuencias de palabras
sentence_tokens = []
for _, row in df[:None].iterrows():
    sentence_tokens.append(text_to_word_sequence(row[0]))

# %%
# Demos un vistazo
sentence_tokens[:2]
# Out:
# [['este',
#   'libro',
#   'trata',
#   'principalmente',
#   'de',
#   'los',
#   'hobbits',
#   'y',
#   'el',
#   'lector',
#   'descubrirá',
#   'en'],
#  ['sus',
#   'páginas',
#   'mucho',
#   'del',
#   'carácter',
#   'y',
#   'algo',
#   'de',
#   'la',
#   'historia',
#   'de',
#   'este',
#   'pueblo',
#   'podrá']]

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []

for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
text_sequences
# Out:
# [['este', 'libro', 'trata', 'principalmente'],
#  ['libro', 'trata', 'principalmente', 'de'],
#  ['trata', 'principalmente', 'de', 'los'],
#  ['principalmente', 'de', 'los', 'hobbits'],
#  ['de', 'los', 'hobbits', 'y'],
#  ['los', 'hobbits', 'y', 'el'],
#  ['hobbits', 'y', 'el', 'lector'],
#  ['y', 'el', 'lector', 'descubrirá']]

# %% [markdown]
# 1.2 - Crear los vectores de palabras (word2vec)
#
# Ahora necesitamos pasarlos a números para que lo entienda la red y separar input de output.
# - El Input seran integers (word2vec)
# - Mientras que el output será one hot encodeado (labels) del tamaño del vocabulario

# %%
tok = Tokenizer() 

# El tokeinzer "aprende" las palabras que se usaran
# Se construye (fit) una vez por proyecto, se aplica N veces (tal cual un encoder)
tok.fit_on_texts(text_sequences) 

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# %%
# Ahora sequences tiene los números "ID", largo 4
sequences
# Out:
# [[10, 8, 6, 1],
#  [8, 6, 1, 2],
#  [6, 1, 2, 3],
#  [1, 2, 3, 4],
#  [2, 3, 4, 5],
#  [3, 4, 5, 7],
#  [4, 5, 7, 9],
#  [5, 7, 9, 11]]

# %%
# Cantidad de casos (doc) de entrada
print(tok.document_count)
# Out:
# 8

# %%
# Cantidad de veces que aparece cada palabra
print(len(tok.word_counts))
# Out:
# 11

# %%
# El índice para cada palabra
# El sistema las ordena de las más populares a las menos populares
print(tok.word_index)
# Out:
# {'principalmente': 1, 'de': 2, 'los': 3, 'hobbits': 4, 'y': 5, 'trata': 6, 'el': 7, 'libro': 8, 'lector': 9, 'este': 10, 'descubrirá': 11}

# %%
# Cantidad de veces quea aparece cada palabra en cada "documento"
# (1 documento = 1 caso de entrada)
print(tok.word_docs)
# Out:
# defaultdict(<class 'int'>, {'libro': 2, 'principalmente': 4, 'este': 1, 'trata': 3, 'de': 4, 'los': 4, 'hobbits': 4, 'y': 4, 'el': 3, 'lector': 2, 'descubrirá': 1})

# %% [markdown]
# ### 2 - Preprocesamiento completo
# Debemos realizar los mismos pasos que en el ejemplo anterior, pero antes de eso debemos transformar ese dataset de filas de oraciones en un texto completo continuo para poder extraer el vocabulario.

# %%
# Vistazo a las primeras filas
df.loc[:15,0]
# Out:
# 0     Este libro trata principalmente de los Hobbits...
# 1     sus páginas mucho del carácter y algo de la hi...
# 2     encontrarse más información en los extractos d...
# 3     Oeste que ya han sido publicados con el título...
# 4     origen en los primeros capítulos del Libro Roj...
# 5     primer Hobbit que fue famoso en el mundo enter...
# 6     una ida y de una vuelta, pues contaba el viaje...
# 7     aventura que más tarde enredaría a todos los H...
# 8                  acontecimientos que aquí se relatan.
# 9      No obstante, muchos querrán saber desde un pr...
# 10    pueblo notable y quizás algunos no tengan el l...
# 11    se han reunido aquí algunas notas sobre los pu...
# 12    tradición hobbit, y se recuerda brevemente la ...
# 13    Los Hobbits son un pueblo sencillo y muy antig...
# 14    tiempos remotos que en la actualidad. Amaban l...
# 15    cultivo de la buena tierra, y no había para el...
# Name: 0, dtype: object

# %%
# Concatenamos todos los rows en un solo valor
corpus = df.apply(lambda row: ' '.join(row.values.astype(str)), axis=0)[0]
corpus
# Out:
# 'Este libro trata principalmente de los Hobbits, y el lector descubrirá en sus páginas mucho del carácter y algo de la historia de este pueblo. Podrá encontrarse más información en los extractos del Libro Rojo de la Frontera del Oeste que ya han sido publicados con el título de El Hobbit. El relato tuvo su origen en los primeros capítulos del Libro Rojo, compuesto por Bilbo Bolsón -el primer Hobbit que fue famoso en el mundo entero - y que él tituló Historia de una ida y de una vuelta, pues contaba el viaje de Bilbo hacia el Este y la vuelta, aventura que más tarde enredaría a todos los Hobbits en los importantes acontecimientos que aquí se relatan.  No obstante, muchos querrán saber desde un principio algo más de este pueblo notable y quizás algunos no tengan el libro anterior. Para esos lectores se han reunido aquí algunas notas sobre los puntos más importantes de la tradición hobbit, y se recuerda brevemente la primera aventura.  Los Hobbits son un pueblo sencillo y muy antiguo, más numeroso en tiempos remotos que en la actualidad. Amaban la paz, la tranquilidad y el cultivo de la buena tierra, y no había para ellos paraje mejor que un campo bien aprovechado y bien ordenado. No entienden ni entendían ni gustan de maquinarias más complicadas que una fragua, un molino de agua o un telar de mano, aunque fueron muy hábiles con toda clase de herramientas. En otros tiempos desconfiaban en general de la Gente Grande, como nos llaman y ahora nos eluden con terror y es difícil encontrarlos. Tienen el oído agudo y la mirada penetrante, y aunque engordan fácilmente y nunca se apresuran si no es necesario, se mueven con agilidad y destreza. Dominaron desde un principio el arte de desaparecer rápido y en silencio, cuando la Gente Grande con la que no querían tropezar se les acercaba casualmente, y han desarrollado este arte hasta el punto de que a los Hombres puede parecerles verdadera magia. Pero los Hobbits jamás han estudiado magia de ninguna índole y esas rápidas desapariciones se deben únicamente a una habilidad profesional, que la herencia, la práctica y una íntima amistad con la tierra han desarrollado tanto que es del todo inimitable para las razas más grandes y desmayadas.  Los Hobbits son gente diminuta, más pequeña que los Enanos; menos corpulenta y fornida, pero no mucho más baja. La estatura es variable, entre los dos y los cuatro pies de nuestra medida. Hoy pocas veces alcanzan los tres pies, pero se dice que en otros tiempos eran más altos. De acuerdo con el Libro Rojo, Bandobras Tuk, apodado el Toro Bramador, hijo de Isengrim Ñ, medía cuatro pies y medio y era capaz de montar a caballo. En los archivos de los Hobbits se cuenta que sólo fue superado por dos famosos personajes de la antigüedad, pero de este hecho curioso se habla en el presente libro.  En cuanto a los Hobbits de la Comarca, de quienes tratan estas relaciones, conocieron en un tiempo la paz y la prosperidad y fueron entonces un pueblo feliz. Vestían ropas de brillantes colores, y preferían el amarillo y el verde; muy rara vez usaban zapatos, pues las plantas de los pies eran en ellos duras como el cuero, fuertes y flexibles y los pies mismos estaban recubiertos de un espeso pelo rizado, muy parecido al pelo de las cabezas, de color castaño casi siempre. Por esta razón el único oficio que practicaban poco era el de zapatero, pero tenían dedos largos y habilidosos que les permitían fabricar muchos otros objetos útiles y agradables. En general los rostros eran bonachones más que hermosos, anchos, de ojos vivos, mejillas rojizas y bocas dispuestas a la risa, a la comida y a la bebida. Reían, comían y bebían a menudo y de buena gana; les gustaban las bromas sencillas en todo momento y comer seis veces al día (cuando podían). Eran hospitalarios, aficionados a las fiestas, hacían regalos espontáneamente y los aceptaban con entusiasmo.  Es en verdad evidente que a pesar de un alejamiento posterior los Hobbits son parientes nuestros: están más cerca de nosotros que  ...

# %%
# Transformar el corpus a tokens
tokens=text_to_word_sequence(corpus)
# Vistazo general de los primeros tokens
tokens[:20]
# Out:
# ['este',
#  'libro',
#  'trata',
#  'principalmente',
#  'de',
#  'los',
#  'hobbits',
#  'y',
#  'el',
#  'lector',
#  'descubrirá',
#  'en',
#  'sus',
#  'páginas',
#  'mucho',
#  'del',
#  'carácter',
#  'y',
#  'algo',
#  'de']

# %%
print("Cantidad de tokens en el corpus:", len(tokens))
# Out:
# Cantidad de tokens en el corpus: 3447

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []
for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
text_sequences[:20]
# Out:
# [['este', 'libro', 'trata', 'principalmente'],
#  ['libro', 'trata', 'principalmente', 'de'],
#  ['trata', 'principalmente', 'de', 'los'],
#  ['principalmente', 'de', 'los', 'hobbits'],
#  ['de', 'los', 'hobbits', 'y'],
#  ['los', 'hobbits', 'y', 'el'],
#  ['hobbits', 'y', 'el', 'lector'],
#  ['y', 'el', 'lector', 'descubrirá'],
#  ['el', 'lector', 'descubrirá', 'en'],
#  ['lector', 'descubrirá', 'en', 'sus'],
#  ['descubrirá', 'en', 'sus', 'páginas'],
#  ['en', 'sus', 'páginas', 'mucho'],
#  ['sus', 'páginas', 'mucho', 'del'],
#  ['páginas', 'mucho', 'del', 'carácter'],
#  ['mucho', 'del', 'carácter', 'y'],
#  ['del', 'carácter', 'y', 'algo'],
#  ['carácter', 'y', 'algo', 'de'],
#  ['y', 'algo', 'de', 'la'],
#  ['algo', 'de', 'la', 'historia'],
#  ['de', 'la', 'historia', 'de']]

# %%
# Proceso de tokenizacion
tok = Tokenizer() 
tok.fit_on_texts(text_sequences) 

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# Damos un vistazo
sequences[:20]
# Out:
# [[27, 51, 356, 357],
#  [51, 356, 357, 1],
#  [356, 357, 1, 2],
#  [357, 1, 2, 12],
#  [1, 2, 12, 3],
#  [2, 12, 3, 6],
#  [12, 3, 6, 358],
#  [3, 6, 358, 359],
#  [6, 358, 359, 4],
#  [358, 359, 4, 101],
#  [359, 4, 101, 360],
#  [4, 101, 360, 66],
#  [101, 360, 66, 11],
#  [360, 66, 11, 189],
#  [66, 11, 189, 3],
#  [11, 189, 3, 124],
#  [189, 3, 124, 1],
#  [3, 124, 1, 5],
#  [124, 1, 5, 59],
#  [1, 5, 59, 1]]

# %%
print("Cantidad de rows del dataset:", len(sequences))
# Out:
# Cantidad de rows del dataset: 3443

# %% [markdown]
# ### 3 - Input y target

# %%
# Con numpy es muy fácil realizar el slicing de vectores
ex = np.array([[1,2,3,4],[5,6,7,8]])
ex
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
# Con numpy es muy fácil realizar el slicing de vectores
print("Dimension:", ex.shape)
print("Todos los elementos:", ex)
print("Todos los elementos menos el último:", ex[:, :-1])
# Out:
# Dimension: (2, 4)
# Todos los elementos: [[1 2 3 4]
#  [5 6 7 8]]
# Todos los elementos menos el último: [[1 2 3]
#  [5 6 7]]

# %%
input = ex[:,:-1] # todos los rows, menos la ultima col
target = ex[:, -1] # última col de cada row

print("Input:", input)
print("Target:", target)
# Out:
# Input: [[1 2 3]
#  [5 6 7]]
# Target: [4 8]

# %%
arr_sequences = np.array(sequences)
x_data = arr_sequences[:,:-1]
y_data_int = arr_sequences[:,-1] # aún falta el oneHotEncoder

print(x_data.shape)
print(y_data_int.shape)
# Out:
# (3443, 3)
# (3443,)

# %%
# Palabras del vocabulario
tok.index_word
# Out:
# {1: 'de',
#  2: 'los',
#  3: 'y',
#  4: 'en',
#  5: 'la',
#  6: 'el',
#  7: 'que',
#  8: 'las',
#  9: 'a',
#  10: 'se',
#  11: 'del',
#  12: 'hobbits',
#  13: 'más',
#  14: 'no',
#  15: 'con',
#  16: 'un',
#  17: 'eran',
#  18: 'o',
#  19: 'por',
#  20: 'una',
#  21: 'pero',
#  22: 'comarca',
#  23: 'como',
#  24: 'lo',
#  25: 'desde',
#  26: 'al',
#  27: 'este',
#  28: 'hombres',
#  29: 'muy',
#  30: 'ellos',
#  31: 'bien',
#  32: 'elfos',
#  33: 'habían',
#  34: 'tierra',
#  35: 'había',
#  36: 'es',
#  37: 'hasta',
#  38: 'entre',
#  39: 'su',
#  40: 'bilbo',
#  41: 'tiempos',
#  42: 'otros',
#  43: 'cuando',
#  44: 'grandes',
#  45: 'era',
#  46: 'tiempo',
#  47: 'oeste',
#  48: 'para',
#  49: 'entonces',
#  50: 'tierras',
#  51: 'libro',
#  52: 'fue',
#  53: 'muchos',
#  54: 'paz',
#  55: 'aunque',
#  56: 'menos',
#  57: 'días',
#  58: 'aún',
#  59: 'historia',
#  60: 'ya',
#  61: 'mundo',
#  62: 'si',
#  63: 'todo',
#  64: 'pies',
#  65: 'norte',
#  66: 'mucho',
#  67: 'pueblo',
#  68: 'han',
#  69: 'pues',
#  70: 'ni',
#  71: 'gente',
#  72: 'grande',
#  73: 'les',
#  74: 'fuertes',
#  75: 'esa',
#  76: 'época',
#  77: 'mar',
#  78: 'montañas',
#  79: 'pelosos',
#  80: 'allí',
#  81: 'rey',
#  82: 'sin',
#  83: 'hobbit',
#  84: 'importantes',
#  85: 'sobre',
#  86: 'ahora',
#  87: 'arte',
#  88: 'enanos',
#  89: 'casi',
#  90: 'tenían',
#  91: 'menudo',
#  92: 'podían',
#  93: 'antes',
#  94: 'allá',
#  95: 'gran',
#  96: 'albos',
#  97: 'durante',
#  98: 'todas',
#  99: 'así',
#  100: 'cosas',
#  101: 'sus',
#  102: 'rojo',
#  103: 'hacia',
#  104: 'son',
#  105: 'fueron',
#  106: 'general',
#  107: 'tuk',
#  108: 'sólo',
#  109: 'quienes',
#  110: 'mismos',
#  111: 'esta',
#  112: 'poco',
#  113: 'donde',
#  114: 'siquiera',
#  115: 'media',
#  116: 'años',
#  117: 'antiguas',
#  118: 'familias',
#  119: 'eriador',
#  120: 'vivieron',
#  121: 'río',
#  122: 'año',
#  123: 'casas',
#  124: 'algo',
#  125: 'sido',
#  126: 'relato',
#  127: 'primeros',
#  128: 'tarde',
#  129: 'todos',
#  130: 'obstante',
#  131: 'principio',
#  132: 'remotos',
#  133: 'buena',
#  134: 'mano',
#  135: 'difícil',
#  136: 'ninguna',
#  137: 'esas',
#  138: 'medida',
#  139: 'tres',
#  140: 'altos',
#  141: 'estas',
#  142: 'preferían',
#  143: 'verde',
#  144: 'vez',
#  145: 'usaban',
#  146: 'estaban',
#  147: 'siempre',
#  148: 'momento',
#  149: 'parientes',
#  150: 'aun',
#  151: 'qué',
#  152: 'embargo',
#  153: 'vivían',
#  154: 'cualquier',
#  155: 'luego',
#  156: 'pronto',
#  157: 'aquellos',
#  158: 'edad',
#  159: 'propios',
#  160: 'también',
#  161: 'primitivas',
#  162: 'bosque',
#  163: 'ramas',
#  164: 'colinas',
#  165: 'orillas',
#  166: 'árboles',
#  167: 'túneles',
#  168: 'sur',
#  169: 'trabajos',
#  170: 'jefes',
#  171: 'todavía',
#  172: 'occidentales',
#  173: 'dúnedain',
#  174: 'reino',
#  175: 'mayoría',
#  176: 'unas',
#  177: 'llamaban',
#  178: 'pocos',
#  179: 'comenzó',
#  180: 'puente',
#  181: 'brandivino',
#  182: 'realidad',
#  183: 'batalla',
#  184: 'ningún',
#  185: 'otras',
#  186: 'llegado',
#  187: 'smials',
#  188: 'muchas',
#  189: 'carácter',
#  190: 'frontera',
#  191: 'tuvo',
#  192: 'origen',
#  193: 'vuelta',
#  194: 'aventura',
#  195: 'aquí',
#  196: 'quizás',
#  197: 'algunos',
#  198: 'amaban',
#  199: 'mejor',
#  200: 'campo',
#  201: 'toda',
#  202: 'clase',
#  203: 'nos',
#  204: 'mirada',
#  205: 'nunca',
#  206: 'necesario',
#  207: 'desarrollado',
#  208: 'puede',
#  209: 'magia',
#  210: 'jamás',
#  211: 'índole',
#  212: 'únicamente',
#  213: 'amistad',
#  214: 'tanto',
#  215: 'pequeña',
#  216: 'dos',
#  217: 'cuatro',
#  218: 'nuestra',
#  219: 'veces',
#  220: 'bandobras',
#  221: 'medio',
#  222: 'cuenta',
#  223: 'famosos',
#  224: 'hecho',
#  225: 'pelo',
#  226: 'razón',
#  227: 'practicaban',
#  228: 'anchos',
#  229: 'regalos',
#  230: 'pesar',
#  231: 'hablaban',
#  232: 'lenguas',
#  233: 'mismas',
#  234: 'mas',
#  235: 'imposible',
#  236: 'relación',
#  237: 'atrás',
#  238: 'algún',
#  239: 'refieren',
#  240: 'otro',
#  241: 'frodo',
#  242: 'tercera',
#  243: 'regiones',
#  244: 'duda',
#  245: 'sabían',
#  246: 'común',
#  247: 'libros',
#  248: 'épocas',
#  249: 'leyendas',
#  250: 'está',
#  251: 'descubrirse',
#  252: 'lenguaje',
#  253: 'pasado',
#  254: 'lejano',
#  255: 'oscuras',
#  256: 'moraban',
#  257: 'anduin',
#  258: 'nubladas',
#  259: 'cruce',
#  260: 'relatos',
#  261: 'llamada',
#  262: 'piel',
#  263: 'llevaban',
#  264: 'botas',
#  265: 'manos',
#  266: 'llanuras',
#  267: 'ríos',
#  268: 'bosques',
#  269: 'montañosas',
#  270: 'mientras',
#  271: 'hábito',
#  272: 'ancestral',
#  273: 'cuevas',
#  274: 'vinieron',
#  275: 'límites',
#  276: 'numerosos',
#  277: 'resto',
#  278: 'cruzaron',
#  279: 'valientes',
#  280: 'clanes',
#  281: 'fuerte',
#  282: 'podía',
#  283: 'tales',
#  284: 'gamos',
#  285: 'lun',
#  286: 'efecto',
#  287: 'reyes',
#  288: 'abundancia',
#  289: 'estaba',
#  290: 'bree',
#  291: 'cuarenta',
#  292: 'comenzaron',
#  293: 'manera',
#  294: 'aprendido',
#  295: 'ese',
#  296: 'olvidaron',
#  297: 'unos',
#  298: 'palabras',
#  299: 'nombres',
#  300: 'mil',
#  301: 'uno',
#  302: 'baranduin',
#  303: 'quebradas',
#  304: 'estado',
#  305: 'transformó',
#  306: 'exterior',
#  307: 'última',
#  308: 'guerra',
#  309: 'thain',
#  310: 'autoridad',
#  311: 'fronteras',
#  312: 'torre',
#  313: 'región',
#  314: 'posible',
#  315: 'vieron',
#  316: 'obligados',
#  317: 'aquello',
#  318: 'cierto',
#  319: 'inmemorial',
#  320: 'clima',
#  321: 'pequeño',
#  322: 'armas',
#  323: 'generalmente',
#  324: 'paredes',
#  325: 'cavada',
#  326: 'corno',
#  327: 'mathoms',
#  328: 'tenía',
#  329: 'moradas',
#  330: 'afición',
#  331: 'ellas',
#  332: 'aquellas',
#  333: 'caso',
#  334: 'piedra',
#  335: 'ricos',
#  336: 'pobres',
#  337: 'vieja',
#  338: 'costumbre',
#  339: 'simples',
#  340: 'estos',
#  341: 'encontraban',
#  342: 'edificar',
#  343: 'principal',
#  344: 'cavernas',
#  345: 'conservaban',
#  346: 'habitantes',
#  347: 'marjala',
#  348: 'cuaderna',
#  349: 'alguno',
#  350: 'edificación',
#  351: 'torres',
#  352: 'verse',
#  353: 'redondas',
#  354: 'genealógicos',
#  355: 'quién',
#  356: 'trata',
#  357: 'principalmente',
#  358: 'lector',
#  359: 'descubrirá',
#  360: 'páginas',
#  361: 'podrá',
#  362: 'encontrarse',
#  363: 'información',
#  364: 'extractos',
#  365: 'publicados',
#  366: 'título',
#  367: 'capítulos',
#  368: 'compuesto',
#  369: 'bolsón',
#  370: 'primer',
#  371: 'famoso',
#  372: 'entero',
#  373: 'él',
#  374: 'tituló',
#  375: 'ida',
#  376: 'contaba',
#  377: 'viaje',
#  378: 'enredaría',
#  379: 'acontecimientos',
#  380: 'relatan',
#  381: 'querrán',
#  382: 'saber',
#  383: 'notable',
#  384: 'tengan',
#  385: 'anterior',
#  386: 'esos',
#  387: 'lectores',
#  388: 'reunido',
#  389: 'algunas',
#  390: 'notas',
#  391: 'puntos',
#  392: 'tradición',
#  393: 'recuerda',
#  394: 'brevemente',
#  395: 'primera',
#  396: 'sencillo',
#  397: 'antiguo',
#  398: 'numeroso',
#  399: 'actualidad',
#  400: 'tranquilidad',
#  401: 'cultivo',
#  402: 'paraje',
#  403: 'aprovechado',
#  404: 'ordenado',
#  405: 'entienden',
#  406: 'entendían',
#  407: 'gustan',
#  408: 'maquinarias',
#  409: 'complicadas',
#  410: 'fragua',
#  411: 'molino',
#  412: 'agua',
#  413: 'telar',
#  414: 'hábiles',
#  415: 'herramientas',
#  416: 'desconfiaban',
#  417: 'llaman',
#  418: 'eluden',
#  419: 'terror',
#  420: 'encontrarlos',
#  421: 'tienen',
#  422: 'oído',
#  423: 'agudo',
#  424: 'penetrante',
#  425: 'engordan',
#  426: 'fácilmente',
#  427: 'apresuran',
#  428: 'mueven',
#  429: 'agilidad',
#  430: 'destreza',
#  431: 'dominaron',
#  432: 'desaparecer',
#  433: 'rápido',
#  434: 'silencio',
#  435: 'querían',
#  436: 'tropezar',
#  437: 'acercaba',
#  438: 'casualmente',
#  439: 'punto',
#  440: 'parecerles',
#  441: 'verdadera',
#  442: 'estudiado',
#  443: 'rápidas',
#  444: 'desapariciones',
#  445: 'deben',
#  446: 'habilidad',
#  447: 'profesional',
#  448: 'herencia',
#  449: 'práctica',
#  450: 'íntima',
#  451: 'inimitable',
#  452: 'razas',
#  453: 'desmayadas',
#  454: 'diminuta',
#  455: 'corpulenta',
#  456: 'fornida',
#  457: 'baja',
#  458: 'estatura',
#  459: 'variable',
#  460: 'hoy',
#  461: 'pocas',
#  462: 'alcanzan',
#  463: 'dice',
#  464: 'acuerdo',
#  465: 'apodado',
#  466: 'toro',
#  467: 'bramador',
#  468: 'hijo',
#  469: 'isengrim',
#  470: 'ñ',
#  471: 'medía',
#  472: 'capaz',
#  473: 'montar',
#  474: 'caballo',
#  475: 'archivos',
#  476: 'superado',
#  477: 'personajes',
#  478: 'antigüedad',
#  479: 'curioso',
#  480: 'habla',
#  481: 'presente',
#  482: 'cuanto',
#  483: 'tratan',
#  484: 'relaciones',
#  485: 'conocieron',
#  486: 'prosperidad',
#  487: 'feliz',
#  488: 'vestían',
#  489: 'ropas',
#  490: 'brillantes',
#  491: 'colores',
#  492: 'amarillo',
#  493: 'rara',
#  494: 'zapatos',
#  495: 'plantas',
#  496: 'duras',
#  497: 'cuero',
#  498: 'flexibles',
#  499: 'recubiertos',
#  500: 'espeso',
#  501: 'rizado',
#  502: 'parecido',
#  503: 'cabezas',
#  504: 'color',
#  505: 'castaño',
#  506: 'único',
#  507: 'oficio',
#  508: 'zapatero',
#  509: 'dedos',
#  510: 'largos',
#  511: 'habilidosos',
#  512: 'permitían',
#  513: 'fabricar',
#  514: 'objetos',
#  515: 'útiles',
#  516: 'agradables',
#  517: 'rostros',
#  518: 'bonachones',
#  519: 'hermosos',
#  520: 'ojos',
#  521: 'vivos',
#  522: 'mejillas',
#  523: 'rojizas',
#  524: 'bocas',
#  525: 'dispuestas',
#  526: 'risa',
#  527: 'comida',
#  528: 'bebida',
#  529: 'reían',
#  530: 'comían',
#  531: 'bebían',
#  532: 'gana',
#  533: 'gustaban',
#  534: 'bromas',
#  535: 'sencillas',
#  536: 'comer',
#  537: 'seis',
#  538: 'día',
#  539: 'hospitalarios',
#  540: 'aficionados',
#  541: 'fiestas',
#  542: 'hacían',
#  543: 'espontáneamente',
#  544: 'aceptaban',
#  545: 'entusiasmo',
#  546: 'verdad',
#  547: 'evidente',
#  548: 'alejamiento',
#  549: 'posterior',
#  550: 'nuestros',
#  551: 'están',
#  552: 'cerca',
#  553: 'nosotros',
#  554: 'antiguamente',
#  555: 'adaptadas',
#  556: 'propia',
#  557: 'modalidad',
#  558: 'preferencias',
#  559: 'aversiones',
#  560: 'descubrir',
#  561: 'consiste',
#  562: 'viene',
#  563: 'antiguos',
#  564: 'perdidos',
#  565: 'olvidados',
#  566: 'conservan',
#  567: 'registro',
#  568: 'desaparecida',
#  569: 'tradiciones',
#  570: 'élfica',
#  571: 'aparecen',
#  572: 'menciona',
#  573: 'obvio',
#  574: 'advirtiese',
#  575: 'existían',
#  576: 'pobló',
#  577: 'extravías',
#  578: 'e',
#  579: 'incontables',
#  580: 'criaturas',
#  581: 'pareció',
#  582: 'insignificante',
#  583: 'heredero',
#  584: 'transformaron',
#  585: 'perturbaron',
#  586: 'concilios',
#  587: 'sabios',
#  588: 'quedado',
#  589: 'conformación',
#  590: 'ha',
#  591: 'cambiado',
#  592: 'noroeste',
#  593: 'viejo',
#  594: 'dónde',
#  595: 'venían',
#  596: 'deseo',
#  597: 'conocimiento',
#  598: 'fuera',
#  599: 'ciencias',
#  600: 'genealógicas',
#  601: 'descendientes',
#  602: 'estudiaban',
#  603: 'recogían',
#  604: 'noticias',
#  605: 'pasadas',
#  606: 'distantes',
#  607: 'recuerdos',
#  608: 'comienzan',
#  609: 'establecieran',
#  610: 'apenas',
#  611: 'remontan',
#  612: 'exodo',
#  613: 'perfectamente',
#  614: 'claro',
#  615: 'través',
#  616: 'costumbres',
#  617: 'desplazaron',
#  618: 'pueblos',
#  619: 'historias',
#  620: 'hay',
#  621: 'referencias',
#  622: 'valles',
#  623: 'lindes',
#  624: 'sabe',
#  625: 'certeza',
#  626: 'emprendieron',
#  627: 'arduo',
#  628: 'peligroso',
#  629: 'entraron',
#  630: 'hablan',
#  631: 'multiplicación',
#  632: 'sombra',
#  633: 'cayó',
#  634: 'floresta',
#  635: 'oscureció',
#  636: 'negro',
#  637: 'cruzar',
#  638: 'dividido',
#  639: 'diferentes',
#  640: 'oscura',
#  641: 'cuerpo',
#  642: 'cara',
#  643: 'lampiña',
#  644: 'proporcionados',
#  645: 'ágiles',
#  646: 'altas',
#  647: 'laderas',
#  648: 'constitución',
#  649: 'sólida',
#  650: 'cabellos',
#  651: 'claros',
#  652: 'delgados',
#  653: 'tuvieron',
#  654: 'estribaciones',
#  655: 'desplazarse',
#  656: 'vagabundearon',
#  657: 'cima',
#  658: 'vientos',
#  659: 'permanecían',
#  660: 'asperas',
#  661: 'especie',
#  662: 'normal',
#  663: 'representativa',
#  664: 'numerosa',
#  665: 'sedentaria',
#  666: 'conservó',
#  667: 'vivir',
#  668: 'temían',
#  669: 'después',
#  670: 'siguieron',
#  671: 'curso',
#  672: 'sonorona',
#  673: 'tharbad',
#  674: 'brunas',
#  675: 'volver',
#  676: 'rama',
#  677: 'nórdica',
#  678: 'amiga',
#  679: 'hábil',
#  680: 'cantos',
#  681: 'manuales',
#  682: 'preferido',
#  683: 'caza',
#  684: 'agricultura',
#  685: 'rivendel',
#  686: 'descendieron',
#  687: 'fontegrís',
#  688: 'mezclaron',
#  689: 'establecidas',
#  690: 'aventureros',
#  691: 'encontraba',
#  692: 'caudillos',
#  693: 'albo',
#  694: 'señores',
#  695: 'país',
#  696: 'encontraron',
#  697: 'moraba',
#  698: 'oesternesse',
#  699: 'iban',
#  700: 'desapareciendo',
#  701: 'rápidamente',
#  702: 'ruina',
#  703: 'alcanzaba',
#  704: 'sitio',
#  705: 'inmigrantes',
#  706: 'empezaron',
#  707: 'establecerse',
#  708: 'comunidades',
#  709: 'ordenadas',
#  710: 'colonias',
#  711: 'quedaba',
#  712: 'recuerdo',
#  713: 'mantenía',
#  714: 'reducida',
#  715: 'tamaño',
#  716: 'chet',
#  717: 'millas',
#  718: 'tempranos',
#  719: 'aprendieron',
#  720: 'alfabeto',
#  721: 'escribir',
#  722: 'usado',
#  723: 'hablaron',
#  724: 'lengua',
#  725: 'oestron',
#  726: 'corriente',
#  727: 'arnor',
#  728: 'gondor',
#  729: 'largo',
#  730: 'costa',
#  731: 'belfalas',
#  732: 'conservaron',
#  733: 'vocablos',
#  734: 'propio',
#  735: 'idioma',
#  736: 'designaban',
#  737: 'meses',
#  738: 'caudal',
#  739: 'personales',
#  740: 'alrededor',
#  741: 'leyenda',
#  742: 'ser',
#  743: 'iniciarse',
#  744: 'cómputo',
#  745: 'seiscientos',
#  746: 'hermanos',
#  747: 'marcho',
#  748: 'blanco',
#  749: 'salieron',
#  750: 'haber',
#  751: 'obtenido',
#  752: 'permiso',
#  753: 'fornost1',
#  754: 'pardo',
#  755: 'séquito',
#  756: 'pasaron',
#  757: 'arbotantes',
#  758: 'construido',
#  759: 'apogeo',
#  760: 'tomaron',
#  761: 'posesión',
#  762: 'extendía',
#  763: 'establecieron',
#  764: 'lejanas',
#  765: 'pidió',
#  766: 'mantuviesen',
#  767: 'buen',
#  768: 'demás',
#  769: 'puentes',
#  770: 'caminos',
#  771: 'ayudaran',
#  772: 'mensajeros',
#  773: 'reconocieran',
#  774: 'majestad',
#  775: 'cronología',
#  776: 'rebautizaron',
#  777: 'fechas',
#  778: 'posteriores',
#  779: 'calcularon',
#  780: 'partir',
#  781: '1',
#  782: 'enamoraron',
#  783: 'seguida',
#  784: 'nueva',
#  785: 'quedaron',
#  786: 'desaparecieron',
#  787: 'súbditos',
#  788: 'formales',
#  789: 'gobernados',
#  790: 'intervenían',
#  791: 'hechos',
#  792: 'fornost',
#  793: 'señor',
#  794: 'mago',
#  795: 'angmar',
#  796: 'enviaron',
#  797: 'arqueros',
#  798: 'ayuda',
#  799: 'afirmaron',
#  800: 'esto',
#  801: 'aparece',
#  802: 'llegó',
#  803: 'fin',
#  804: 'apropiaron',
#  805: 'eligieron',
#  806: 'asumió',
#  807: 'desaparecido',
#  808: 'ininterrumpida',
#  809: 'rica',
#  810: 'generosa',
#  811: 'desierta',
#  812: 'cultivada',
#  813: 'granjas',
#  814: 'maizales',
#  815: 'viñedos',
#  816: 'pie',
#  817: 'leguas',
#  818: 'cincuenta',
#  819: 'páramos',
#  820: 'pantanos',
#  821: 'denominaron',
#  822: 'bajo',
#  823: 'distrito',
#  824: 'organizados',
#  825: 'placentero',
#  826: 'rincón',
#  827: 'llevaron',
#  828: 'vida',
#  829: 'ordenada',
#  830: 'dieron',
#  831: 'cada',
#  832: 'importancia',
#  833: 'movían',
#  834: 'llegar',
#  835: 'pensar',
#  836: 'norma',
#  837: 'derecho',
#  838: 'sensato',
#  839: 'ignoraron',
#  840: 'sabido',
#  841: 'guardianes',
#  842: 'hicieron',
#  843: 'larga',
#  844: 'protegidos',
#  845: 'recordaban',
#  846: 'amantes',
#  847: 'lucharon',
#  848: 'sí',
#  849: 'luchar',
#  850: 'subsistir',
#  851: 'antigua',
#  852: 'comienzo',
#  853: 'única',
#  854: 'libró',
#  855: 'dentro',
#  856: 'ocurrió',
#  857: 'campos',
#  858: 'verdes',
#  859: '1147',
#  860: 'cc',
#  861: 'desbarató',
#  862: 'invasión',
#  863: 'orcos',
#  864: 'mismo',
#  865: 'hizo',
#  866: 'apacible',
#  867: 'lobos',
#  868: 'devorándolo',
#  869: 'rudos',
#  870: 'inviernos',
#  871: 'blancos',
#  872: 'cuentos',
#  873: 'viejas',
#  874: 'arsenal',
#  875: 'trofeos',
#  876: 'colgaba',
#  877: 'chimeneas',
#  878: 'coleccionaba',
#  879: 'museo',
#  880: 'conocido',
#  881: 'hogar',
#  882: 'mathom',
#  883: 'uso',
#  884: 'inmediato',
#  885: 'tampoco',
#  886: 'decidían',
#  887: 'desechar',
#  888: 'cantidades',
#  889: 'pasaban',
#  890: 'ocio',
#  891: 'alterado',
#  892: 'raro',
#  893: 'vigor',
#  894: 'intimidarlos',
#  895: 'matarlos',
#  896: 'incansable',
#  897: 'mostraban',
#  898: 'buenas',
#  899: 'renunciar',
#  900: 'lograban',
#  901: 'sobrevivir',
#  902: 'rigores',
#  903: 'adversidad',
#  904: 'enemigos',
#  905: 'asombrando',
#  906: 'conocían',
#  907: 'veían',
#  908: 'barrigas',
#  909: 'caras',
#  910: 'regordetas',
#  911: 'resistían',
#  912: 'pelear',
#  913: 'mataban',
#  914: 'deporte',
#  915: 'criatura',
#  916: 'viviente',
#  917: 'acosaba',
#  918: 'manejar',
#  919: 'presentaba',
#  920: 'tiraban',
#  921: 'arco',
#  922: 'certera',
#  923: 'puntería',
#  924: 'recogía',
#  925: 'ponerse',
#  926: 'resguardo',
#  927: 'inmediatamente',
#  928: 'bestias',
#  929: 'merodeadoras',
#  930: 'vivido',
#  931: 'subterráneas',
#  932: 'creían',
#  933: 'sentían',
#  934: 'gusto',
#  935: 'transcurso',
#  936: 'adoptar',
#  937: 'viviendas',
#  938: 'mantenían',
#  939: 'continuaron',
#  940: 'viviendo',
#  941: 'madrigueras',
#  942: 'agujeros',
#  943: 'sola',
#  944: 'ventana',
#  945: 'edificaban',
#  946: 'versiones',
#  947: 'lujosas',
#  948: 'excavaciones',
#  949: 'terrenos',
#  950: 'adecuados',
#  951: 'ramificados',
#  952: 'parte',
#  953: 'distritos',
#  954: 'bajos',
#  955: 'multiplicaban',
#  956: 'nivel',
#  957: 'suelo',
#  958: 'villas',
#  959: 'hobbiton',
#  960: 'alforzada',
#  961: 'vecindad',
#  962: 'blancas',
#  963: 'madera',
#  964: 'ladrillo',
#  965: 'preferidas',
#  966: 'molineros',
#  967: 'herreros',
#  968: 'cordeleros',
#  969: 'carreteros',
#  970: 'porque',
#  971: 'vivieran',
#  972: 'construir',
#  973: 'cobertizos',
#  974: 'talleres',
#  975: 'graneros',
#  976: 'dicen',
#  977: 'piernas',
#  978: 'enano',
#  979: 'barro',
#  980: 'ignoraba',
#  981: 'proporción',
#  982: 'sangre',
#  983: 'notaba',
#  984: 'vello',
#  985: 'crecía',
#  986: 'barbillas',
#  987: 'rastro',
#  988: 'barba',
#  989: 'instalaron',
#  990: 'reciente',
#  991: 'peculiares',
#  992: 'extrañas',
#  993: 'lugar',
#  994: 'oficios',
#  995: 'proviniera',
#  996: 'pudieron',
#  997: 'haberlo',
#  998: 'maestros',
#  999: 'juventud',
#  1000: 'alto',
#  ...}

# %%
# Cantidad de palabras en el vocabulario
vocab_size = len(tok.word_counts)
vocab_size
# Out:
# 1107

# %%
# Transformar los datos a oneHotEncoding
y_data = to_categorical(y_data_int, num_classes=vocab_size)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-51c0d3e0c52c> in <module>()
#       1 # Transformar los datos a oneHotEncoding
# ----> 2 y_data = to_categorical(y_data_int, num_classes=vocab_size)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      69   n = y.shape[0]
#      70   categorical = np.zeros((n, num_classes), dtype=dtype)
# ---> 71   categorical[np.arange(n), y] = 1
#      72   output_shape = input_shape + (num_classes,)
#      73   categorical = np.reshape(categorical, output_shape)
#
# IndexError: index 1107 is out of bounds for axis 1 with size 1107

# %%
# En el caso anterior explota porque y_data_int comienza en "1" en vez de "0"
# valor minimo:
min(y_data_int)
# Out:
# 1

# %%
y_data_int_offset = y_data_int - 1
y_data = to_categorical(y_data_int_offset, num_classes=vocab_size) 
y_data.shape
# Out:
# (3443, 1107)

# %% [markdown]
# ### 4 - Entrenar el modelo

# %%
# largo de la secuencia de entrada
input_seq_len = x_data.shape[1] 
input_seq_len
# Out:
# 3

# %%
# Largo del vector de salida --> vocab_size
output_size = vocab_size
output_size
# Out:
# 1107

# %%
model = Sequential()

# Embedding:
# input_seq_len = 3 --> ingreso 3 palabras
# input_dim = vocab_size --> 1628 palabras distintas
# output_dim = 5 --> crear embeddings de tamaño 3 (tamaño variable y ajustable)
model.add(Embedding(input_dim=vocab_size+1, output_dim=5, input_length=input_seq_len))

model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64)) # La última capa LSTM no lleva return_sequences
model.add(Dense(32, activation='relu'))

# Predicción de clasificación con softmax
# La salida vuelve al espacio de 1628 palabras posibles
model.add(Dense(vocab_size, activation='softmax'))

# Clasificación multiple categórica --> loss = categorical_crossentropy
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 3, 5)              5540
#
#  lstm_2 (LSTM)               (None, 3, 64)             17920
#
#  dropout_1 (Dropout)         (None, 3, 64)             0
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1107)              36531
#
# =================================================================
# Total params: 95,095
# Trainable params: 95,095
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_data, y_data, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 87/87 [==============================] - 5s 15ms/step - loss: 6.5678 - accuracy: 0.0527 - val_loss: 6.0397 - val_accuracy: 0.0769
# Epoch 2/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.7618 - accuracy: 0.0545 - val_loss: 6.2022 - val_accuracy: 0.0769
# Epoch 3/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.6965 - accuracy: 0.0588 - val_loss: 6.3276 - val_accuracy: 0.0769
# Epoch 4/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.6556 - accuracy: 0.0527 - val_loss: 6.4306 - val_accuracy: 0.0769
# Epoch 5/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.6186 - accuracy: 0.0559 - val_loss: 6.5415 - val_accuracy: 0.0566
# Epoch 6/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.5819 - accuracy: 0.0548 - val_loss: 6.6944 - val_accuracy: 0.0769
# Epoch 7/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.5588 - accuracy: 0.0588 - val_loss: 6.8434 - val_accuracy: 0.0769
# Epoch 8/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.5313 - accuracy: 0.0563 - val_loss: 6.7785 - val_accuracy: 0.0769
# Epoch 9/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.4982 - accuracy: 0.0577 - val_loss: 6.9333 - val_accuracy: 0.0552
# Epoch 10/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.4562 - accuracy: 0.0595 - val_loss: 7.0371 - val_accuracy: 0.0769
# Epoch 11/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.4313 - accuracy: 0.0577 - val_loss: 7.1773 - val_accuracy: 0.0769
# Epoch 12/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.4138 - accuracy: 0.0585 - val_loss: 7.2185 - val_accuracy: 0.0421
# Epoch 13/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.3992 - accuracy: 0.0577 - val_loss: 7.3836 - val_accuracy: 0.0769
# Epoch 14/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.3883 - accuracy: 0.0588 - val_loss: 7.4028 - val_accuracy: 0.0769
# Epoch 15/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.3771 - accuracy: 0.0505 - val_loss: 7.5107 - val_accuracy: 0.0769
# Epoch 16/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.3709 - accuracy: 0.0505 - val_loss: 7.4812 - val_accuracy: 0.0769
# Epoch 17/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.3523 - accuracy: 0.0595 - val_loss: 7.4766 - val_accuracy: 0.0769
# Epoch 18/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.3421 - accuracy: 0.0585 - val_loss: 7.7062 - val_accuracy: 0.0769
# Epoch 19/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.3338 - accuracy: 0.0563 - val_loss: 7.5336 - val_accuracy: 0.0682
# Epoch 20/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.3175 - accuracy: 0.0610 - val_loss: 7.6810 - val_accuracy: 0.0740
# Epoch 21/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.3048 - accuracy: 0.0585 - val_loss: 7.7807 - val_accuracy: 0.0639
# Epoch 22/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.2824 - accuracy: 0.0566 - val_loss: 7.9077 - val_accuracy: 0.0697
# Epoch 23/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.2631 - accuracy: 0.0563 - val_loss: 7.8074 - val_accuracy: 0.0653
# Epoch 24/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.2273 - accuracy: 0.0556 - val_loss: 7.7787 - val_accuracy: 0.0435
# Epoch 25/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.1972 - accuracy: 0.0592 - val_loss: 7.8120 - val_accuracy: 0.0450
# Epoch 26/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.1639 - accuracy: 0.0581 - val_loss: 7.8509 - val_accuracy: 0.0464
# Epoch 27/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.1296 - accuracy: 0.0610 - val_loss: 7.7366 - val_accuracy: 0.0464
# Epoch 28/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.0952 - accuracy: 0.0599 - val_loss: 7.9252 - val_accuracy: 0.0421
# Epoch 29/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.0621 - accuracy: 0.0643 - val_loss: 8.0147 - val_accuracy: 0.0450
# Epoch 30/100
# 87/87 [==============================] - 1s 8ms/step - loss: 5.0306 - accuracy: 0.0694 - val_loss: 7.9927 - val_accuracy: 0.0450
# Epoch 31/100
# 87/87 [==============================] - 1s 7ms/step - loss: 5.0011 - accuracy: 0.0628 - val_loss: 8.1663 - val_accuracy: 0.0421
# Epoch 32/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.9717 - accuracy: 0.0683 - val_loss: 8.2319 - val_accuracy: 0.0392
# Epoch 33/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.9470 - accuracy: 0.0748 - val_loss: 8.2578 - val_accuracy: 0.0348
# Epoch 34/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.9142 - accuracy: 0.0748 - val_loss: 8.2235 - val_accuracy: 0.0421
# Epoch 35/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.8787 - accuracy: 0.0741 - val_loss: 8.3818 - val_accuracy: 0.0406
# Epoch 36/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.8573 - accuracy: 0.0759 - val_loss: 8.6176 - val_accuracy: 0.0421
# Epoch 37/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.8320 - accuracy: 0.0752 - val_loss: 8.7264 - val_accuracy: 0.0392
# Epoch 38/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.8156 - accuracy: 0.0850 - val_loss: 8.6503 - val_accuracy: 0.0377
# Epoch 39/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.7894 - accuracy: 0.0802 - val_loss: 8.7466 - val_accuracy: 0.0392
# Epoch 40/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.7724 - accuracy: 0.0784 - val_loss: 9.0225 - val_accuracy: 0.0435
# Epoch 41/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.7527 - accuracy: 0.0810 - val_loss: 9.0230 - val_accuracy: 0.0406
# Epoch 42/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.7265 - accuracy: 0.0821 - val_loss: 9.3154 - val_accuracy: 0.0450
# Epoch 43/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.7000 - accuracy: 0.0799 - val_loss: 9.1638 - val_accuracy: 0.0406
# Epoch 44/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.6772 - accuracy: 0.0868 - val_loss: 9.4673 - val_accuracy: 0.0392
# Epoch 45/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.6593 - accuracy: 0.0832 - val_loss: 9.6027 - val_accuracy: 0.0392
# Epoch 46/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.6457 - accuracy: 0.0871 - val_loss: 9.6715 - val_accuracy: 0.0421
# Epoch 47/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.6214 - accuracy: 0.0868 - val_loss: 9.8601 - val_accuracy: 0.0421
# Epoch 48/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.6023 - accuracy: 0.0864 - val_loss: 10.1886 - val_accuracy: 0.0421
# Epoch 49/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.5829 - accuracy: 0.0919 - val_loss: 10.0402 - val_accuracy: 0.0377
# Epoch 50/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.5640 - accuracy: 0.0919 - val_loss: 10.1439 - val_accuracy: 0.0450
# Epoch 51/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.5572 - accuracy: 0.0926 - val_loss: 10.5101 - val_accuracy: 0.0479
# Epoch 52/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.5309 - accuracy: 0.0969 - val_loss: 10.2572 - val_accuracy: 0.0464
# Epoch 53/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.4932 - accuracy: 0.0908 - val_loss: 10.3933 - val_accuracy: 0.0508
# Epoch 54/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.4712 - accuracy: 0.0969 - val_loss: 10.6250 - val_accuracy: 0.0566
# Epoch 55/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.4413 - accuracy: 0.0980 - val_loss: 10.8574 - val_accuracy: 0.0653
# Epoch 56/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.4298 - accuracy: 0.0966 - val_loss: 10.7924 - val_accuracy: 0.0581
# Epoch 57/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.4121 - accuracy: 0.1009 - val_loss: 10.6934 - val_accuracy: 0.0537
# Epoch 58/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.3895 - accuracy: 0.0984 - val_loss: 10.9601 - val_accuracy: 0.0624
# Epoch 59/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.3696 - accuracy: 0.0980 - val_loss: 11.2453 - val_accuracy: 0.0697
# Epoch 60/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.3404 - accuracy: 0.1013 - val_loss: 11.0741 - val_accuracy: 0.0581
# Epoch 61/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.3209 - accuracy: 0.1068 - val_loss: 11.2342 - val_accuracy: 0.0639
# Epoch 62/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.2832 - accuracy: 0.1031 - val_loss: 11.6181 - val_accuracy: 0.0595
# Epoch 63/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.2634 - accuracy: 0.1046 - val_loss: 11.6309 - val_accuracy: 0.0624
# Epoch 64/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.2522 - accuracy: 0.1064 - val_loss: 11.5893 - val_accuracy: 0.0595
# Epoch 65/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.2284 - accuracy: 0.1035 - val_loss: 11.4426 - val_accuracy: 0.0552
# Epoch 66/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.2067 - accuracy: 0.1082 - val_loss: 11.8119 - val_accuracy: 0.0581
# Epoch 67/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.1664 - accuracy: 0.1100 - val_loss: 12.0504 - val_accuracy: 0.0610
# Epoch 68/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.1688 - accuracy: 0.1122 - val_loss: 12.0040 - val_accuracy: 0.0595
# Epoch 69/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.1398 - accuracy: 0.1064 - val_loss: 12.2106 - val_accuracy: 0.0566
# Epoch 70/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.1043 - accuracy: 0.1137 - val_loss: 12.5309 - val_accuracy: 0.0552
# Epoch 71/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.0964 - accuracy: 0.1147 - val_loss: 12.4913 - val_accuracy: 0.0653
# Epoch 72/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.0692 - accuracy: 0.1147 - val_loss: 12.5261 - val_accuracy: 0.0610
# Epoch 73/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.0452 - accuracy: 0.1129 - val_loss: 12.7451 - val_accuracy: 0.0595
# Epoch 74/100
# 87/87 [==============================] - 1s 8ms/step - loss: 4.0366 - accuracy: 0.1162 - val_loss: 12.8833 - val_accuracy: 0.0639
# Epoch 75/100
# 87/87 [==============================] - 1s 7ms/step - loss: 4.0072 - accuracy: 0.1209 - val_loss: 13.0677 - val_accuracy: 0.0552
# Epoch 76/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.9913 - accuracy: 0.1187 - val_loss: 13.1052 - val_accuracy: 0.0610
# Epoch 77/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.9746 - accuracy: 0.1231 - val_loss: 13.2866 - val_accuracy: 0.0610
# Epoch 78/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.9525 - accuracy: 0.1231 - val_loss: 13.3332 - val_accuracy: 0.0595
# Epoch 79/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.9346 - accuracy: 0.1249 - val_loss: 13.4396 - val_accuracy: 0.0566
# Epoch 80/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.9201 - accuracy: 0.1285 - val_loss: 13.5568 - val_accuracy: 0.0581
# Epoch 81/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.8959 - accuracy: 0.1296 - val_loss: 13.7474 - val_accuracy: 0.0566
# Epoch 82/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.8875 - accuracy: 0.1267 - val_loss: 13.7744 - val_accuracy: 0.0566
# Epoch 83/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.8667 - accuracy: 0.1347 - val_loss: 14.2185 - val_accuracy: 0.0581
# Epoch 84/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.8452 - accuracy: 0.1285 - val_loss: 14.1775 - val_accuracy: 0.0595
# Epoch 85/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.8329 - accuracy: 0.1333 - val_loss: 14.2604 - val_accuracy: 0.0624
# Epoch 86/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.8118 - accuracy: 0.1340 - val_loss: 14.2024 - val_accuracy: 0.0610
# Epoch 87/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.7820 - accuracy: 0.1340 - val_loss: 14.4154 - val_accuracy: 0.0653
# Epoch 88/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.7619 - accuracy: 0.1376 - val_loss: 14.6808 - val_accuracy: 0.0595
# Epoch 89/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.7530 - accuracy: 0.1402 - val_loss: 14.7547 - val_accuracy: 0.0566
# Epoch 90/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.7493 - accuracy: 0.1383 - val_loss: 14.8458 - val_accuracy: 0.0610
# Epoch 91/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.7327 - accuracy: 0.1358 - val_loss: 14.6533 - val_accuracy: 0.0566
# Epoch 92/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.7215 - accuracy: 0.1387 - val_loss: 14.8919 - val_accuracy: 0.0552
# Epoch 93/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.7026 - accuracy: 0.1442 - val_loss: 15.0174 - val_accuracy: 0.0566
# Epoch 94/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.6948 - accuracy: 0.1420 - val_loss: 15.1202 - val_accuracy: 0.0552
# Epoch 95/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.6687 - accuracy: 0.1471 - val_loss: 15.1697 - val_accuracy: 0.0595
# Epoch 96/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.6435 - accuracy: 0.1554 - val_loss: 15.5765 - val_accuracy: 0.0581
# Epoch 97/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.6456 - accuracy: 0.1347 - val_loss: 15.4463 - val_accuracy: 0.0595
# Epoch 98/100
# 87/87 [==============================] - 1s 7ms/step - loss: 3.6144 - accuracy: 0.1514 - val_loss: 15.3736 - val_accuracy: 0.0624
# Epoch 99/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.5999 - accuracy: 0.1485 - val_loss: 15.5529 - val_accuracy: 0.0624
# Epoch 100/100
# 87/87 [==============================] - 1s 8ms/step - loss: 3.6113 - accuracy: 0.1449 - val_loss: 15.5347 - val_accuracy: 0.0581

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Entrenamiento
epoch_count = range(1, len(hist.history['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_accuracy'], label='valid')
plt.show()

# %% [markdown]
# ### 5 - Predicción de próxima palabra

# %%
# Keras pad_sequences
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/sequence/pad_sequences
# Si la secuencia de entrada supera al input_seq_len (3) se trunca
# Si la secuencia es más corta se agregna ceros al comienzo

# %%
# Se utilizará gradio para ensayar el modelo
# Herramienta poderosa para crear interfaces rápidas para ensayar modelos
# https://gradio.app/
import sys
# !{sys.executable} -m pip install gradio --quiet
# Out:
#      |████████████████████████████████| 1.7 MB 24.1 MB/s
#      |████████████████████████████████| 84 kB 3.1 MB/s
#      |████████████████████████████████| 255 kB 74.5 MB/s
#      |████████████████████████████████| 2.0 MB 57.4 MB/s
#      |████████████████████████████████| 54 kB 3.6 MB/s
#      |████████████████████████████████| 53 kB 2.6 MB/s
#      |████████████████████████████████| 211 kB 77.8 MB/s
#      |████████████████████████████████| 1.1 MB 62.7 MB/s
#      |████████████████████████████████| 271 kB 77.4 MB/s
#      |████████████████████████████████| 94 kB 2.8 MB/s
#      |████████████████████████████████| 144 kB 73.0 MB/s
#      |████████████████████████████████| 58 kB 7.7 MB/s
#      |████████████████████████████████| 10.9 MB 63.1 MB/s
#      |████████████████████████████████| 79 kB 10.5 MB/s
#      |████████████████████████████████| 43 kB 2.6 MB/s
#      |████████████████████████████████| 3.6 MB 60.4 MB/s
#      |████████████████████████████████| 856 kB 64.9 MB/s
#      |████████████████████████████████| 61 kB 561 kB/s
#      |████████████████████████████████| 58 kB 7.2 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
import gradio as gr

def model_response(human_text):

    # Encodeamos
    encoded = tok.texts_to_sequences([human_text])[0]
    # Si tienen distinto largo
    encoded = pad_sequences([encoded], maxlen=3, padding='pre')
    
    # Predicción softmax
    y_hat = model.predict(encoded).argmax(axis=-1)

    # Debemos buscar en el vocabulario la palabra
    # que corresopnde al indice (y_hat) predicho por le modelo
    out_word = ''
    for word, index in tok.word_index.items():
        if index == y_hat:
            out_word = word
            break

    # Agrego la palabra a la frase predicha
    return human_text + ' ' + out_word

iface = gr.Interface(
    fn=model_response,
    inputs=["textbox"],
    outputs="text",
    layout="vertical")

iface.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://38769.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
#         <iframe
#             width="900"
#             height="500"
#             src="https://38769.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Keyboard interruption in main thread... closing server.
# (<fastapi.applications.FastAPI at 0x7f6ba88e7350>,
#  'http://127.0.0.1:7860/',
#  'https://38769.gradio.app')

# %% [markdown]
# ### 6 - Generación de secuencias nuevas

# %%
def generate_seq(model, tokenizer, seed_text, max_length, n_words):
    """
        Exec model sequence prediction

        Args:
            model (keras): modelo entrenado
            tokenizer (keras tokenizer): tonenizer utilizado en el preprocesamiento
            seed_text (string): texto de entrada (input_seq)
            max_length (int): máxima longitud de la sequencia de entrada
            n_words (int): números de palabras a agregar a la sequencia de entrada
        returns:
            output_text (string): sentencia con las "n_words" agregadas
    """
    output_text = seed_text
	# generate a fixed number of words
    for _ in range(n_words):
		# Encodeamos
        encoded = tokenizer.texts_to_sequences([output_text])[0]
		# Si tienen distinto largo
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
		
		# Predicción softmax
        y_hat = model.predict(encoded).argmax(axis=-1)
		# Vamos concatenando las predicciones
        out_word = ''

        # Debemos buscar en el vocabulario la palabra
        # que corresopnde al indice (y_hat) predicho por le modelo
        for word, index in tokenizer.word_index.items():
            if index == y_hat:
                out_word = word
                break

		# Agrego las palabras a la frase predicha
        output_text += ' ' + out_word
    return output_text

# %%
input_text='Hace mucho tiempo'

generate_seq(model, tok, input_text, max_length=3, n_words=3)
# Out:
# 'Hace mucho tiempo   '

# %% [markdown]
# ### 7 - Conclusiones
# El modelo entrenado tuvo un muy mail desempeño en el entrenamiento además de overfitting. Cuestiones que podrían mejorarse:
# - Agregar más capas o neuronaes
# - Incrementar la cantidad de épocas
# - Agregar BRNN
#
# Es importante destacar que en este ejemplo estamos entrenando nuestro propios Embeddings, y para ello se requiere mucha data. En los ejemplos que realizaremos de aquí en más utilizaremos más datos, embeddings pre-enternados o modelos pre-entrenados.
